# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Housing.csv')

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
data.shape
# Out:
# (545, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
import seaborn as sns
sns.set()
sns.displot(data['price'])

# %%
sns.displot(data['area'])

# %%
sns.countplot(data['bedrooms'].astype(str))
# Out:
# <Axes: xlabel='count', ylabel='bedrooms'>

# %%
sns.countplot(data['bathrooms'].astype(str))
# Out:
# <Axes: xlabel='count', ylabel='bathrooms'>

# %%
sns.pairplot(data, hue = 'bathrooms', x_vars=['bedrooms'], y_vars=['area'])

# %%
sns.countplot(data['stories'].astype(str))
# Out:
# <Axes: xlabel='count', ylabel='stories'>

# %%
sns.countplot(data['mainroad'])
# Out:
# <Axes: xlabel='count', ylabel='mainroad'>

# %%
sns.countplot(data['guestroom'])
# Out:
# <Axes: xlabel='count', ylabel='guestroom'>

# %%
sns.countplot(data['basement'])
# Out:
# <Axes: xlabel='count', ylabel='basement'>

# %%
sns.countplot(data['hotwaterheating'])
# Out:
# <Axes: xlabel='count', ylabel='hotwaterheating'>

# %%
sns.countplot(data['airconditioning'])
# Out:
# <Axes: xlabel='count', ylabel='airconditioning'>

# %%
sns.countplot(data['parking'].astype(str))
# Out:
# <Axes: xlabel='count', ylabel='parking'>

# %%
sns.countplot(data['prefarea'])
# Out:
# <Axes: xlabel='count', ylabel='prefarea'>

# %%
sns.countplot(data['furnishingstatus'])
# Out:
# <Axes: xlabel='count', ylabel='furnishingstatus'>

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
cat = 'mainroad guestroom basement hotwaterheating airconditioning prefarea furnishingstatus'.split()
cat
# Out:
# ['mainroad',
#  'guestroom',
#  'basement',
#  'hotwaterheating',
#  'airconditioning',
#  'prefarea',
#  'furnishingstatus']

# %%
num = 'area bedrooms bathrooms stories parking'.split()
num
# Out:
# ['area', 'bedrooms', 'bathrooms', 'stories', 'parking']

# %%
dummy = pd.get_dummies(data['furnishingstatus'], drop_first = True)
dummy = dummy.astype(int)
dummy
# Out:
#      semi-furnished  unfurnished
# 0                 0            0
# 1                 0            0
# 2                 1            0
# 3                 0            0
# 4                 0            0
# ..              ...          ...
# 540               0            1
# 541               1            0
# 542               0            1
# 543               0            0
# 544               0            1
#
# [545 rows x 2 columns]

# %%
data = pd.concat([data,dummy],axis = 1)

# %%
data.drop('furnishingstatus', axis = 1, inplace = True)

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
x = data.drop('price', axis = 1)
y = data['price']

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    7420         4          2        3      yes        no       no
# 1    8960         4          4        4      yes        no       no
# 2    9960         3          2        2      yes        no      yes
# 3    7500         4          2        2      yes        no      yes
# 4    7420         4          1        2      yes       yes      yes
# ..    ...       ...        ...      ...      ...       ...      ...
# 540  3000         2          1        1      yes        no      yes
# 541  2400         3          1        1       no        no       no
# 542  3620         2          1        1      yes        no       no
# 543  2910         3          1        1       no        no       no
# 544  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea  semi-furnished  \
# 0                no             yes        2      yes               0
# ...

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 42)

# %%
x_train
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 46   6000         3          2        4      yes        no       no
# 93   7200         3          2        1      yes        no      yes
# 335  3816         2          1        1      yes        no      yes
# 412  2610         3          1        2      yes        no      yes
# 471  3750         3          1        2      yes        no       no
# ..    ...       ...        ...      ...      ...       ...      ...
# 71   6000         4          2        4      yes        no       no
# 106  5450         4          2        1      yes        no      yes
# 270  4500         3          2        3      yes        no       no
# 435  4040         2          1        1      yes        no       no
# 102  5500         3          2        4      yes       yes       no
#
#     hotwaterheating airconditioning  parking prefarea  semi-furnished  \
# 46               no             yes        1       no               0
# ...

# %%
x_test
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 316  5900         4          2        2       no        no      yes
# 77   6500         3          2        3      yes        no       no
# 360  4040         2          1        1      yes        no       no
# 90   5000         3          1        2      yes        no       no
# 493  3960         3          1        1      yes        no       no
# ..    ...       ...        ...      ...      ...       ...      ...
# 15   6000         4          1        2      yes        no      yes
# 357  6930         4          1        2       no        no       no
# 39   6000         4          2        4      yes        no       no
# 54   6000         3          2        2      yes       yes       no
# 155  6100         3          2        1      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea  semi-furnished  \
# 316              no              no        1       no               0
# ...

# %%
y_train
# Out:
# 46     7525000
# 93     6300000
# 335    3920000
# 412    3430000
# 471    3010000
#         ...
# 71     6755000
# 106    6160000
# 270    4340000
# 435    3290000
# 102    6195000
# Name: price, Length: 436, dtype: int64

# %%
y_test
# Out:
# 316    4060000
# 77     6650000
# 360    3710000
# 90     6440000
# 493    2800000
#         ...
# 15     9100000
# 357    3773000
# 39     7910000
# 54     7350000
# 155    5530000
# Name: price, Length: 109, dtype: int64

# %%
scale = 'area bedrooms bathrooms stories parking '.split()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
x_train[scale] = scaler.fit_transform(x_train[scale])

# %%
x_train
# Out:
#          area  bedrooms  bathrooms   stories mainroad guestroom basement  \
# 46   0.298969       0.4   0.333333  1.000000      yes        no       no
# 93   0.381443       0.4   0.333333  0.000000      yes        no      yes
# 335  0.148866       0.2   0.000000  0.000000      yes        no      yes
# 412  0.065979       0.4   0.000000  0.333333      yes        no      yes
# 471  0.144330       0.4   0.000000  0.333333      yes        no       no
# ..        ...       ...        ...       ...      ...       ...      ...
# 71   0.298969       0.6   0.333333  1.000000      yes        no       no
# 106  0.261168       0.6   0.333333  0.000000      yes        no      yes
# 270  0.195876       0.4   0.333333  0.666667      yes        no       no
# 435  0.164261       0.2   0.000000  0.000000      yes        no       no
# 102  0.264605       0.4   0.333333  1.000000      yes       yes       no
#
#     hotwaterheating airconditioning   parking prefarea  semi-furnished  \
# ...

# %%
x_test[scale] = scaler.transform(x_test[scale])
x_test
# Out:
#          area  bedrooms  bathrooms   stories mainroad guestroom basement  \
# 316  0.292096       0.6   0.333333  0.333333       no        no      yes
# 77   0.333333       0.4   0.333333  0.666667      yes        no       no
# 360  0.164261       0.2   0.000000  0.000000      yes        no       no
# 90   0.230241       0.4   0.000000  0.333333      yes        no       no
# 493  0.158763       0.4   0.000000  0.000000      yes        no       no
# ..        ...       ...        ...       ...      ...       ...      ...
# 15   0.298969       0.6   0.000000  0.333333      yes        no      yes
# 357  0.362887       0.6   0.000000  0.333333       no        no       no
# 39   0.298969       0.6   0.333333  1.000000      yes        no       no
# 54   0.298969       0.4   0.333333  0.333333      yes       yes       no
# 155  0.305842       0.4   0.333333  0.000000      yes        no      yes
#
#     hotwaterheating airconditioning   parking prefarea  semi-furnished  \
# ...

# %%
x_train[scale].std()
# Out:
# area         0.151499
# bedrooms     0.149561
# bathrooms    0.159130
# stories      0.286031
# parking      0.284980
# dtype: float64

# %%
label = 'mainroad guestroom basement hotwaterheating airconditioning prefarea'.split()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in label:
  x_train[i] = le.fit_transform(x_train[i])
  x_test[i] = le.fit_transform(x_test[i])

# %%
x_train
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 46   0.298969       0.4   0.333333  1.000000         1          0         0
# 93   0.381443       0.4   0.333333  0.000000         1          0         1
# 335  0.148866       0.2   0.000000  0.000000         1          0         1
# 412  0.065979       0.4   0.000000  0.333333         1          0         1
# 471  0.144330       0.4   0.000000  0.333333         1          0         0
# ..        ...       ...        ...       ...       ...        ...       ...
# 71   0.298969       0.6   0.333333  1.000000         1          0         0
# 106  0.261168       0.6   0.333333  0.000000         1          0         1
# 270  0.195876       0.4   0.333333  0.666667         1          0         0
# 435  0.164261       0.2   0.000000  0.000000         1          0         0
# 102  0.264605       0.4   0.333333  1.000000         1          1         0
#
# ...

# %%
x_test
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 316  0.292096       0.6   0.333333  0.333333         0          0         1
# 77   0.333333       0.4   0.333333  0.666667         1          0         0
# 360  0.164261       0.2   0.000000  0.000000         1          0         0
# 90   0.230241       0.4   0.000000  0.333333         1          0         0
# 493  0.158763       0.4   0.000000  0.000000         1          0         0
# ..        ...       ...        ...       ...       ...        ...       ...
# 15   0.298969       0.6   0.000000  0.333333         1          0         1
# 357  0.362887       0.6   0.000000  0.333333         0          0         0
# 39   0.298969       0.6   0.333333  1.000000         1          0         0
# 54   0.298969       0.4   0.333333  0.333333         1          1         0
# 155  0.305842       0.4   0.333333  0.000000         1          0         1
#
# ...

# %%
print(x_train.std())
# Out:
# area               0.151499
# bedrooms           0.149561
# bathrooms          0.159130
# stories            0.286031
# mainroad           0.349658
# guestroom          0.383708
# basement           0.479903
# hotwaterheating    0.219141
# airconditioning    0.461921
# parking            0.284980
# prefarea           0.423824
# semi-furnished     0.495812
# unfurnished        0.464738
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)
pred
# Out:
# array([5164653.90033967, 7224722.29802166, 3109863.24240339,
#        4612075.32722559, 3294646.25725956, 3532275.09556558,
#        5611774.56836474, 6368145.98732718, 2722856.95689986,
#        2629405.61585784, 9617039.50315578, 2798087.30447888,
#        3171096.76847064, 3394639.09125529, 3681088.65424276,
#        5263187.74621486, 3035963.47612386, 4786122.8004005 ,
#        4349551.9200572 , 3572362.09930451, 5774875.21395649,
#        5886993.57919882, 2730836.19518459, 4727316.47323636,
#        5244847.527168  , 7555324.21605602, 3220790.84680269,
#        5191898.79934208, 8143726.91009782, 3398814.09825036,
#        6490693.05027925, 3315105.90747811, 6708457.36761325,
#        4201738.21071676, 3557571.06735186, 5836974.50478626,
#        4808660.67448476, 4362878.73613262, 3191242.95701508,
#        4596554.93225239, 4566042.8604841 , 3517779.52374148,
#        7205844.79365835, 3983597.27861103, 3749338.70271055,
# ...

# %%
from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error,mean_squared_error
print(mean_absolute_error(y_test,pred))
print(mean_squared_error(y_test,pred))
print(np.sqrt(mean_squared_error(y_test,pred)))
print(r2_score(y_test,pred))
# Out:
# 970043.4039201648
# 1754318687330.6697
# 1324506.960091441
# 0.6529242642153172

# %%
pred.mean()
# Out:
# 4861481.335616184

# %%
plt.scatter(y_test, pred)

# %% [markdown]
# Our model's prediction accuracy is over 65%
